# %%
import os
from datasets import load_dataset
from PIL import Image
import pandas as pd
import torch

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_colwidth', None) # Show full content of each column (no truncation)
pd.set_option('display.width', None)

# %%
dataset = load_dataset("ahmedheakl/arocrbench_synthesizear",split="train")

# %%
dataset
# Out:
# Dataset({
#     features: ['image', 'text', 'source'],
#     num_rows: 500
# })

# %%
results = []
for sample in dataset:
    image = sample["image"]  # Already a PIL Image object
    if image.mode != "RGB":
        image = image.convert("RGB")
    ground_truth = sample["text"]
    results.append({
        "image": image,
        "ground_truth": ground_truth,
        "qwenv2.5_3B": None,
        
    })
print(f"Initialized results with {len(results)} samples.")
# Out:
# Initialized results with 500 samples.

# %% [markdown]
# ## Qwenvl2.5 3B

# %%
from transformers import AutoProcessor, AutoModelForImageTextToText

processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-3B-Instruct",use_fast=True)

model = AutoModelForImageTextToText.from_pretrained("Qwen/Qwen2.5-VL-3B-Instruct",torch_dtype="auto",device_map="cuda:0")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from PIL import Image 
import requests

# %%
image = dataset[2]['image']
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=994x163>

# %%
dataset[2]['text']
# Out:
# 'تُثِير فِيها الاسود، وَهُوَ ما يَتَعارَض مَعَ اِكْتِشافِ'

# %%
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
            },
            {
                "type": "text",
                "text": "extract the arabic text in the following image"
            }
        ]
    }
]

text_prompt = processor.apply_chat_template(messages, add_generation_prompt=True)

# %%
def qwen_extract_ocr(text_prompt,image):
    
    inputs = processor(
        text = [text_prompt],
        images = [image],
        padding = True,
        return_tensors = "pt"
    )

    inputs = inputs.to("cuda")

    output_ids = model.generate(**inputs, max_new_tokens=1024)

    generated_ids = [
        output_ids[len(input_ids) :]
        for input_ids, output_ids in zip(inputs.input_ids, output_ids)
    ]

    output_text = processor.batch_decode(
        generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True
    )
    return output_text

# %%
image = dataset[2]['image']
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=994x163>

# %%
qwen_extract_ocr(text_prompt,image=dataset[2]['image'])
# Out:
# ['The Arabic text in the image is:\n\nتُثير فيها الأسود، وهو ما يتعارض مع اكتشاف']

# %%
for i, sample in enumerate(results):
    torch.cuda.empty_cache()
    image = sample['image'].resize((512,512))
    text_result = " ".join(qwen_extract_ocr(text_prompt,image=image)).replace("The Arabic text in the image is:\n\n","")
    print(text_result)
    print("*****"*40)
    results[i]['qwenv2.5_3B'] = text_result
# Out:
# وَإِذا ما سَأَلْتَنِي عَن مَعْنَى لَفظَةٍ "عُرب" عِندَ
# ********************************************************************************************************************************************************************************************************
# أَنْ تُفْهَمَ النُّصُوصِ وَإِسْتِنْبَاطُ مَعْنَاهَا يُوجَدُ صَحِيحٌ تَفَقِيقٌ
# ********************************************************************************************************************************************************************************************************
# "تُظهر فيها الأسود، وهو ما يتغافض مع اكتشاف"
# ********************************************************************************************************************************************************************************************************
# الجماعي، وظلت تصل إلى المرحلة الاشتراكية لسيطرة أكبر
# ********************************************************************************************************************************************************************************************************
# مَا هُوَ مُنْبِذٌ فِيهِ دَرَقَاتٍ وَفَطْعَ أَحْمَسْخَاجٍ مُّرْتَدٌ
# ********************************************************************************************************************************************************************************************************
# "إلى المدارس العامة، وهم يُكنّ في كثير من"
# ********************************************************************************************************************************************************************************************************
# "لتسنّ إقامة الأجنحة الحُراريّة وحلاً للقدرة على استغلال الطاقة الشمسية في المناطق الصحراوية."
# ********************************************************************************************************************************************************************************************************
# "القرص وتكنو جذبنا الشفاءات في انستا يليها"
# ********************************************************************************************************************************************************************************************************
# من الناجية "الجيم لجحية" فإن باطن البالان وخذة لا
# ********************************************************************************************************************************************************************************************************
# وَيُحْكِمُ تَحْدِيدٌ مَجْمُوْعَةٌ مِنَ الْعَوْامِنِ المُفَقَسْرَةَ بِهِذَا الأَدْوِعِ
# ********************************************************************************************************************************************************************************************************
# تَأثَّرتُ بِمَهَةِ بَيْنَ (إِرْم)، فَكَنتُ بِهَا، مَا فَعَل
# ********************************************************************************************************************************************************************************************************
# تُكون فارسيه، لأَن الفروس مجوس، والمجوس لا يُعتقدون
# ********************************************************************************************************************************************************************************************************
# العربية،
# ********************************************************************************************************************************************************************************************************
# "اللَّهُمَّ بِمَا نَصَبْتَ لِقَوْصِ الْقُرْآنِ عَلَى حَكُومٍ فِي الْبَلَدِينَ"
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# "تُحِلُّ السُّؤُودُ إِلَٰهَةً بِكُلَّ حَرَمٍ، وَفِصْلًا عَنِ ذلك"
# ********************************************************************************************************************************************************************************************************
# استعمل التصميمات الحرفية لإبراز أشكال الأبنية وديمومة البناء.
# ********************************************************************************************************************************************************************************************************
# أو تلكَ صَنَبَ خُصُوبَةَ الموسمِ، وَفِي نهايةَ الحصاد
# ********************************************************************************************************************************************************************************************************
# "بِالْحُسْنِ مُؤْذِنَاتِ الْهُدَىِ وَمُؤْمِنٌ بِالْإِيمَانِ"
# ********************************************************************************************************************************************************************************************************
# "الانضمام في اتحاد المغرب العربي برنامجا دون إقليمي."
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# هناك تحدّث فيه تقاعدك نموذجياً تصل زوجيّة الخرازة
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# "كَذَبَ نَجَحْ بِمُظْلَمَةٍ مِّنْ صَوْتِهِ وَبِصَغْرِهِ وَكُرْفِهِ وَبِرُوحِ رَائِقٍ غَيْرِ مُؤْمِنٍ"
#
# This translates to:
#
# "He lied and succeeded with his voice, his youth, and his cunning, and with a lively spirit that was not of a believer."
# ********************************************************************************************************************************************************************************************************
# "تُشكّلُ القيَّادُاتُ المتَبادِلِيَّةُ، وَتَقعُ في شمالها وَفي"
# ********************************************************************************************************************************************************************************************************
# بُنِتَ شَاعِرُ الصَّينِ الكَبِيرِ لِيَ بَايٍ فِي زَقْنِي
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# أَنَا فِي الْحَجِّ هُلْ تَقْلُمْ فَاتِّبِعْ لِكُلِّ مَا أَتَيْتَ إِلَيْكَ إِذَا نَصَّْ
# ********************************************************************************************************************************************************************************************************
# "أساسية، وتدربهم على تقوّي"
# ********************************************************************************************************************************************************************************************************
# "مع البيئة الدائنية وخصوصيتها التقليدية كما تضمّن مشروع"
# ********************************************************************************************************************************************************************************************************
# "عَلَى شُوْرَحِ أَجَامِيلِهِ، يُنْظَلِقُ إِيْضَا عَلَى أَهْمَتِيهِ شَعْرُ"
#
# This translates to English as:
#
# "On the shoulders of his beauties, it also flows on his hair."
# ********************************************************************************************************************************************************************************************************
# وَقَدْ ذَهَبَ بَعْضُهُمْ إِلَى رِيْانِ العَرَبِيَّةِ الشَّرَقِيَّةِ كَانَتْ
# ********************************************************************************************************************************************************************************************************
# "للطاقة ومياهها تستخدم الأرض حرارتها التي تحتاجها"
# ********************************************************************************************************************************************************************************************************
# "أَنْ تُفْرِجَ عَنِّي فِي جَابِرٍ وَقَدْ أَسْرَى مِنْ أَهْلِيَ"
# ********************************************************************************************************************************************************************************************************
# "يَسْتَنْفِرُونَ قُصِّرَةٌ مَرْجِعَةٌ غَزْبًا وَأَشْتَتَّوْنَ قُلُوبَ يَتْيَمْ"
#
# This translates to English as:
#
# "They will gather together, short and long, for plundering and they will gather together hearts of the orphaned."
# ********************************************************************************************************************************************************************************************************
# "فَيُؤْمِنُ الْخَلَالُ وَيُؤْمِنُ الْخَلَالُ إِلَّا مَا تُؤْمِنُونَ"
# ********************************************************************************************************************************************************************************************************
# "فَإِنْ كُنتُمْ أَخْرِجْتُمْ مِنَ الْأَرْضِ شَدَّةً"
# ********************************************************************************************************************************************************************************************************
# "وَأَنْ أَنْتُمْ لَا تَعْلَمُونَ نَفْعَ رِزْقِكُمْ بِالْعَصْرِ"
# ********************************************************************************************************************************************************************************************************
# الأحمر
# ********************************************************************************************************************************************************************************************************
# أَقْلَ الحُرُومِ، فَقَدْ غَرَّسَتْ فِي مَناطِقِ مِنَ الْجَزِيرَةِ
# ********************************************************************************************************************************************************************************************************
# التدريبية والتكوين، خطط يدعم قوي من قبل أعلى
# ********************************************************************************************************************************************************************************************************
# الريفيات اللّتي كُملَن في المُدنِ وَاللّتي لم يُغادِرْن
# ********************************************************************************************************************************************************************************************************
# وَ أَشَارُوا فِي خَدِيعٍ هُم إِلَى أَنْ نُسْتَقْوِيَاتٌ
# ********************************************************************************************************************************************************************************************************
# مرحلة التكلم الثانوية
# ********************************************************************************************************************************************************************************************************
# العَريقِيُّ الحاِصمُ المُفيدُ وَالْمُشْتَقِبٌ المُنشُرُ
# ********************************************************************************************************************************************************************************************************
# أخيراً لم تكن جميعها نصوصاً حميرية
# ********************************************************************************************************************************************************************************************************
# وَبَيَّنَ اللَّهُ إِلَى أَهْمَاتِهِ كُثُرٌ الْفَاسِقُونَ العَادُودُينَ
# ********************************************************************************************************************************************************************************************************
# "الإنسان هو الإنسان، والحياة هي الحياة، والحب هو الحب، والسلام هو السلام، والصبر هو الصبر، والصداقة هي الصداقة، والعمل هو العمل، والتعلم هو التعلم، والصحة هي الصحة، والسعادة هي السعادة."
# ********************************************************************************************************************************************************************************************************
# وطرَّقِ الإنتاج بُدْنِ مستوياتٍ إخراً، حيثُ كنت العلاقةُ
# ********************************************************************************************************************************************************************************************************
# "من أجمل جدید شباب الأشجار ونجسین"
# ********************************************************************************************************************************************************************************************************
# كتاب الأخ الأشتاذ / على مُضْطَفَى المُصْرِيّين
# ********************************************************************************************************************************************************************************************************
# "كَنْ بُخَّلِ جِنْبًا سُهْرَةٌ وَقَطِيبَ جِنْبًا سُهْرَةٌ"
# ********************************************************************************************************************************************************************************************************
# مُشْتَقَهِ مِن فِعْلٍ شائع
# ********************************************************************************************************************************************************************************************************
# عِندما تَقوميَه في الشعر الجاهليّ
# ********************************************************************************************************************************************************************************************************
# في بحر الموسى، أو حائل بقائيا نهر، أثْرَت
# ********************************************************************************************************************************************************************************************************
# للشَّعْرِ يُنْدَجَّ الجَاهِلِيَّينِ إِلَّا أَنَا لاَ نَجِدُ حملاً
# ********************************************************************************************************************************************************************************************************
# العربية
# ********************************************************************************************************************************************************************************************************
# "وَ اِتَّقُوا رَبَّكُمْ وَ فِي نَفْسِكُمْ رَبُّكُمْ أَضْلَعُ وَ دَعْ"
#
# This translates to English as:
#
# "And fear your Lord, and in yourselves is your Lord's Presence. He knows what you do."
# ********************************************************************************************************************************************************************************************************
# "الْأَخْتِمَامُ مِنْ أَحْيَاءِ الْأَوَّلِينَ وَأَحْيَاءِ الْثَانِينَ"
# ********************************************************************************************************************************************************************************************************
# "فَعَنَ الشَّيْخُ الْأَدْيَنِ إِخْتَارُوا بَقَائِلِ بَلَادِ الْعَرَبِ،"
#
# This translates to:
#
# "According to the Sheikh Al-Dine, they chose the inhabitants of the Arab lands."
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# "الحُكْمُ يَنْصُرُ الْمُؤْمِنَينَ - يَنْصُرُهُمْ اللهُ وَيَجْعَلُهُمْ مُؤْمِنِينَ"
# ********************************************************************************************************************************************************************************************************
# الجوّيّة وعين أشعة الشمس مُخَرَّقٌ من نهيه وعين إشعاع
# ********************************************************************************************************************************************************************************************************
# المُفَقِيَّة بِشكل واضح. وهذا من وجهة نظرنا ما
# ********************************************************************************************************************************************************************************************************
# في ذاك العام وهدا يعود ألسنا إلى بيسنيّة
# ********************************************************************************************************************************************************************************************************
# "لَجِل، فُرُوَّةُ مُهْدِبِ إِبْنِ رَأْسٍ أَخْفَمُ يَصْحَبُ"
# ********************************************************************************************************************************************************************************************************
# "الفرق بين الأداء وَهُمْ الشَّيْخُونَ وَفَقَرَ الإِخْرَاجُ"
# ********************************************************************************************************************************************************************************************************
# إلى عثّر حبيبة وذهاباً إلا أنه يُضع العَرض
# ********************************************************************************************************************************************************************************************************
# الصحيحة في الدارس القائمة ولداس الجديده بناء الدارس
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# يُرجَّى أَصْحَاب هَذِه النَّظَرِيَّة عَلَى أَن شَدَّة الأَشْعَة
# ********************************************************************************************************************************************************************************************************
# تَكْلُوْنِ المُهَجِّرِ مِعَ قَالَمٍ اللَّغَةِ الصَّحَفِيَّةِ بِأَصْمَعِ القَوْمِ
# ********************************************************************************************************************************************************************************************************
# وقد بَقِيت بعض المواضع المذكورة نستَفيق مفادها في
# ********************************************************************************************************************************************************************************************************
# "الْيَوْمِ أَنْتُمْ أَلَّا تَكُونُوا كُفُوًا بِهِ وَأَنْتُمْ رَحْمَةٌ لِّلْعَالَمِينَ"
# ********************************************************************************************************************************************************************************************************
# "أنت مهماً كأنك أمه أو زوجتك ونسبيه ونسبيين"
# ********************************************************************************************************************************************************************************************************
# مُجْمَعٌ مَعِنظام تشغيل التناهيد (وندوز)، وَمِنْ نُمَّ
# ********************************************************************************************************************************************************************************************************
# "مُؤخِرُ الأَجْلِ يُحِبُّ [الْيَوْمُ الْفَاتِحُ]"
# ********************************************************************************************************************************************************************************************************
# أحمد بن زيد
# ********************************************************************************************************************************************************************************************************
# "هلاً! أنتِ رُبّةٌ وَأنا صاحِبٌ، قال:"
#
# This translates to English as:
#
# "Hello! You are the master and I am the servant, said:"
# ********************************************************************************************************************************************************************************************************
# من ناحية وُجِي لسيا من ناحية اخري، على
# ********************************************************************************************************************************************************************************************************
# "لأننا نعيش في عصر التكنولوجيا والابتكارات الصناعية والتقنية، ثم تحسينها وتطويرها بسرعة كبيرة."
# ********************************************************************************************************************************************************************************************************
# عن طريق الأشعة الكهرومغناطيسية التي تتمحور بالغلاف الجويّ
# ********************************************************************************************************************************************************************************************************
# صُورِ اِلمَدَّةِ الرَقِيمِهِ مِن مِلْفَاتٍ تَتَّصَمَّمُ مَخْضُوطَاتٍ غَيْرِي
# ********************************************************************************************************************************************************************************************************
# "الشَّهَادَةُ وَالْكِتَابُ وَالْحَجَرُ أَوْلَىٰ بِالْقَبْلِ مِنْ شَيْءٍ"
#
# This translates to English as:
#
# "The testimony and the book and the rock are better than anything else."
# ********************************************************************************************************************************************************************************************************
# إِلَّا حُوَّى أَيْضًا أَنْ مُ 2 أَفْجَةٌ لِلشَّاسِشِ بِحُوَّ وَ إِسْتَنْتَجْمَا
# ********************************************************************************************************************************************************************************************************
# "أشرفيه، ونَعْشِرُكَ، وَنَجْزِيُكَ رَبُّكَ كَيْفًا"
#
# This translates to English as:
#
# "Enjoy it, and may you live long, and may your Lord reward you well."
# ********************************************************************************************************************************************************************************************************
# لَحْنُ تَوَّالِ الخَلِيجِ خَلا فَا لَدُّوَالٍ أَخْرَى كَثِيرَةٌ مَازَالَتْ
# ********************************************************************************************************************************************************************************************************
# يُنصح من البيانات الأولى بفحص الخدمة أن أكثر
# ********************************************************************************************************************************************************************************************************
# "كملة وآخرى لمح ريداء الى نهرو انفسهم بقلاب المناز"
# ********************************************************************************************************************************************************************************************************
# وَتَبْيَتِّجَةٌ لِكَفُونِ هَذَا الْفَازٍ لا يَشْتَغل ولا يُساعِد
# ********************************************************************************************************************************************************************************************************
# في البداية، ثم محاولة التركيب وتتعلم الروح. إذا
# ********************************************************************************************************************************************************************************************************
# أُولى ما تُستَشفُ
#
# This translates to "The first thing you will discover" or "The first thing you will find out."
# ********************************************************************************************************************************************************************************************************
# المرتبات العالية لازُوج في الصين، ويعتقد أنه أحدث
# ********************************************************************************************************************************************************************************************************
# وَالْسَّنَينَ
# ********************************************************************************************************************************************************************************************************
# طَهَّبُ
# ********************************************************************************************************************************************************************************************************
# "يُعتقد أنَّ هذه الأدوات تُستخدم لِتَعليم الأطفال الرُّباعيَّة، وَالْأَدوات الْمُستخدمة تُختلف حسب نوع المدرسة والْكِتاب."
# ********************************************************************************************************************************************************************************************************
# "الأفضل المبيعات. كانت تلك واحدة من اللحظات الهامة."
# ********************************************************************************************************************************************************************************************************
# وَقُدْ عَتِبَّ وَرَجَى أَنَّ الْإِنْطَامَ امْتَلَلَنَّ رَعَهُ هُوَ أَلْبَيْعِي
# ********************************************************************************************************************************************************************************************************
# "أرجّح المُهَجِّرة، لا أُعَدَّها إِلَّا رَّوْيَةٌ"
#
# This translates to English as:
#
# "I prefer the migrated, I do not consider them except as a narration."
# ********************************************************************************************************************************************************************************************************
# السياق، يُجِدُ التأكيد على ضرورة ننسى خميس هذه
# ********************************************************************************************************************************************************************************************************
# يَتَّابَعُ دَبٌ فِيهِ وَ يَتَّعَلَّمُ الطَّاعَةُ
# ********************************************************************************************************************************************************************************************************
# وَإِذَا كَانَ الْقُدُّاسُ قُدَّ أَخْطَاءًا فِي قَوْمٍ قَعْفٌ
# ********************************************************************************************************************************************************************************************************
# "نابضة للإيدو، ومن الملاحظ أن الإشعاع الشمسي يُنشَدُّ"
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# "الجواب: 18"
# ********************************************************************************************************************************************************************************************************
# كُلّا في ذُلكَ الوَطنِ الجديد
# ********************************************************************************************************************************************************************************************************
# الاستفسارات العَمِيْشِيَّة القادِرة على بلورة المشاريع الكبرى
# ********************************************************************************************************************************************************************************************************
# "عطروط و هلال خازن عفيف للحج. بدأت قوافل الاحجيج حاخ أرّ"
#
# This translates to:
#
# "Citropt and Halal safe and fragrant for Hajj. The Hajj pilgrims' caravans began."
# ********************************************************************************************************************************************************************************************************
# وَتُشْعِبُ نَفْسِهَا بُعْدَ جُوعٍ وَعِطَشٍ، وَتَفْرَحُ الْإِبْنُ وَيُذْكِرُ
# ********************************************************************************************************************************************************************************************************
# للإقامة فيه يُبقيهم ويتناول طلائعهم. الحظُ ماليّة
# ********************************************************************************************************************************************************************************************************
# التنافس في تنفييم كل جديد باللغة المحلية
# ********************************************************************************************************************************************************************************************************
# خض، بس ش، صغّه
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# "هَذِهِ الْحَقْوَاقُ هَلْ تُفْلِحُ قَبْلَ الْمَرْحَةِ أَنْ تُجْرَى بِالْمَسْدِيَةِ الْأَخْرَى"
#
# This translates to English as:
#
# "These rights will they not succeed before the hour of death, if they are not carried by the last measure?"
# ********************************************************************************************************************************************************************************************************
# الْمَوْجُودِةِ عَلَى سُطُحِ الأرضِ وَطَمْحَةٌ لَا رَضِيَ اللهُ عَنْهَا وَأُصِبْرًا
# ********************************************************************************************************************************************************************************************************
# "بدء أعمال خاصة في الريف، معززاً في هذا"
# ********************************************************************************************************************************************************************************************************
# مُشمشيس دراق، غيظ، ناء، بث، نشر
# ********************************************************************************************************************************************************************************************************
# "استعماً في مؤلفات الحمداني"
# ********************************************************************************************************************************************************************************************************
# في حساباتها، وأن أخبرنا خلاصة
# ********************************************************************************************************************************************************************************************************
# في الأذور والآتاج وهو كذلك الإمتياز عن فعلٍ
# ********************************************************************************************************************************************************************************************************
# من اختلاف أنيي الكتاب في رحم الحروف وتقريها
# ********************************************************************************************************************************************************************************************************
# "ذَٰلِكَ الْمُهْدِيدُ، ذَٰلِكَ الْمُهْتَدِّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَدُّ، ذَٰلِكَ الْمُهْتَ
# ********************************************************************************************************************************************************************************************************
# والثَلْب، والظَّالِمُ والشَّاهِينَ، وبَعْدَ الشَّأْوَ وَالقَطَامِي وَنَحْوَ ذَلِكَ.
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# لهم، ويشترون من أصحاب تلك السُّفَرِ هم تُدْهِمُوا
# ********************************************************************************************************************************************************************************************************
# "رقيبه، تشبهُ في ذكاءِ من جانين فخَّارتها وجهه الأزرق"
#
# This translates to:
#
# "His neck, resembles in intelligence from two women who sewed their faces and blue eyes."
# ********************************************************************************************************************************************************************************************************
# صباح الخير
# ********************************************************************************************************************************************************************************************************
# "إِنْ تَوَفَّى بِالْكِتَابِ وَسَلَّمَ الْأَفْطُرِ بِطَارِقٍ يُؤْمِنُ يَا عَزَّ وَجَاهِدْ"
#
# This translates to English as:
#
# "If death comes by the Book and the fast is completed with a door, who will believe? O Allah, be exalted and be a fighter."
# ********************************************************************************************************************************************************************************************************
# حَفْرُ الرَّسْمِ عَلَى الخَشْبِ. وَكَلَّى مَدَّى أَكْثَرُ
# ********************************************************************************************************************************************************************************************************
# "يتفاوت الاختيارات المصرفية والمصرفية في مجالات الزراعة"
#
# This translates to English as:
#
# "The banking options and banking services differ in agricultural fields."
# ********************************************************************************************************************************************************************************************************
# أُسْرَىٰ تَلْغَ وَسُونِغَ، حَيْثُ كَانَتْ اللِّسْنَةُ الْإِيْسِسِيَّةُ أَلْتَيْ
#
# This translates to English as:
#
# "Captured Talaq and Sonug, where the Issei language was spoken."
# ********************************************************************************************************************************************************************************************************
# "البومذكراقي في فاز الخير الشقاقى القماري استقر في خمسة"
# ********************************************************************************************************************************************************************************************************
# كان ما يُنصص وَقْتًا لِقراءة أعمالٍ مُطْبوعه بالحَكّاء
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# الْأَرْضِ وَعُدْنَهَا تَصْلِي إِلَى صَلَاحَةٍ السَّمَاءِ وَسَفَرْتُ نَتَمَكَّن الْأَنْبِيَاءُ
# ********************************************************************************************************************************************************************************************************
# جزء لعقاقير الأعشاب
# ********************************************************************************************************************************************************************************************************
# "يُنَبِّهُ هَذِهِ الْجَامِعَاتُ لِتُحِقْ لَهَا، وَأَزَّ يَنْ "
# ********************************************************************************************************************************************************************************************************
# الإلهي، التَّكْتُبة في رِبَا أَحْكَمُ اجْتُمِعَ فِي اِقْتَاعٍ وَبَعْضُ
# ********************************************************************************************************************************************************************************************************
# "عدي و أبي البغتري"
# ********************************************************************************************************************************************************************************************************
# بِشَرِينَ نُؤْمِعُ أَوْ سَيَلِكُهُ حَجَرًا فِيهِ، وَهُوَ الْأَقْيَانَ يُغْتَبِّي
# ********************************************************************************************************************************************************************************************************
# وَسُجِّلُ مَايَاسَاتٍ وَمَا مُخْ لِلأَحْسَامِ وَما إِلَى ذَٰلكَ
# ********************************************************************************************************************************************************************************************************
# مَنْ تَفَاتَوْنَ بِذَل
# ********************************************************************************************************************************************************************************************************
# يُؤْذِي إِنْعَادُ كُرْكُبٍ لَا أُرْضِ
# ********************************************************************************************************************************************************************************************************
# فيها أيضاً خَجَازَةُ بِزْكَانِيَهِ والظَّاهِرِ إِنَّها كانت مِن
# ********************************************************************************************************************************************************************************************************
# الشُّرَبِيَّةُ لَا هَا إِلَى فُتْنَقِي الْحُدُودِ بِالْعَرَبِيَّةِ السُّعِيدَةِ. وَ
# ********************************************************************************************************************************************************************************************************
# "الجنة المبينة، وكذلك كلان رزقهم أمانات الحبة"
# ********************************************************************************************************************************************************************************************************
# عَيْنِيُّ وَأَكْبَرُ إِلَٰكِ بِالكِتَابِ مِنْ خَلَالِ نَمْحَةٍ وَكَثْرَةٍ أَنتِ مُهَمَّدٌ
# ********************************************************************************************************************************************************************************************************
# "تكريم الطيّاح ورفيق خلق الشهادتين الأُجلاس الإشْتِبَارَة"
# ********************************************************************************************************************************************************************************************************
# "أُخْتَرْتُ رَأْيًا مَّا بَلَّتُ أَرْسَلْتُ عَلَيْكُمْ إِلَى الشَّهِيرِ بِإِحْصَانِ الْمُتَّقِينَ"
# ********************************************************************************************************************************************************************************************************
# "الإيجاد والبحث والتحليل الذي كانت تُستلم فيه 1620 و 1621"
# ********************************************************************************************************************************************************************************************************
# فيه، وَتَعْمِلُ أَحْلِمَا إِلَى الزِّرَاوَةِ والدَّسْتَقْرَارِ مِثْلًا مَدِينَيْنَ
# ********************************************************************************************************************************************************************************************************
# العلماء رأوا أن التغييرات الطارئة على غطاء
# ********************************************************************************************************************************************************************************************************
# بِذَلِكَ فَتَعَافَى صَوْرُ حُمَا كُُّمْ
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# ذَكَّسَ مُهْمِيدٌ - بَطَلْعَهُ أُولَى صَغِيرَةً مُؤْلَفَةً مِنْ
# ********************************************************************************************************************************************************************************************************
# "إلى ما يشيا كله. قال سنجاده وهو أبو سعيد"
#
# This translates to:
#
# "To what you have brought. Said Sajjadah, who was Abu Saeed."
# ********************************************************************************************************************************************************************************************************
# وفي اليمن، حيث تمثل ثقافة المجتمع جُملة من
# ********************************************************************************************************************************************************************************************************
# ثَمَّ فَلَهُ مِثْيَادًا مُّنذُ سُنُوٍّ طِرْوَا وَتَكَارَّ سُكَانٌ
# ********************************************************************************************************************************************************************************************************
# بَنْفِسِ اللُّه
# ********************************************************************************************************************************************************************************************************
# "رُبِّهَا بَعْضُكُمْ لِيُرَاشَ أَفْرَجُوا أَنْ "
# ********************************************************************************************************************************************************************************************************
# وبِيَّنَا يُمِيلُ الْبَعْضُ إِلَى عَدْم التَّفْصِيَلِ هَٰذَا يَبِينُ
# ********************************************************************************************************************************************************************************************************
# عادة قديمة جدًا، ربما رافقت الإنسان منذ يوم
# ********************************************************************************************************************************************************************************************************
# تُعلمهم في الماضي. أهداف تعليم الكبار وبناء عَلَى
# ********************************************************************************************************************************************************************************************************
# "شَاءَ سَمْ وَتَصُورِ الْكَانُونَاتِ اعْتِقَادَةٌ فِي المَنْطَقَةِ الْقَرَّيْبَةِ"
#
# This translates to English as:
#
# "Let him hear and imagine the laws of belief in the nearby region."
# ********************************************************************************************************************************************************************************************************
# والأرتفاع يشتبه نتائج التقييم البشرية
# ********************************************************************************************************************************************************************************************************
# "والأقليّة العربيّة، بكلّ ما لديهما من إرث"
# ********************************************************************************************************************************************************************************************************
# "إِنَّمَا أَنَا لِيُرِيدُ أَنْ تَتَّقَّنَّ مَا كُنتُمْ أَوْ فِيمَا تَعْلَمُونَ"
# ********************************************************************************************************************************************************************************************************
# "أُتيَّ سُوعُعُباً فَيَاتَىَ عَشْرُ كيلومتراتٍ في الساعةَ بين"
# ********************************************************************************************************************************************************************************************************
# "كأن البحر والقارس صحولاً كأنه سماً كأنه قَ..."
#
# This translates to English as:
#
# "As if the sea and the river were awake, as if it were heaven, as if it were..."
#
# The text appears to be a poetic or metaphorical expression.
# ********************************************************************************************************************************************************************************************************
# قَبِيلَةٌ وَكُذا الْهُجُرَةِ وَالْحَجُّ وَيُعْدُّ هَل يُؤَاخِذُ
# ********************************************************************************************************************************************************************************************************
# "الولايات المتحدة. حينها فقط وصل الكتاب إلى القمة."
# ********************************************************************************************************************************************************************************************************
# "نُجِّي ١٪ من مُناحيّة كُرْدَنٌ مُنّا الأُجُيّر"
#
# This translates to English as:
#
# "We saved 1% of the water used by the people of Kurdistan."
# ********************************************************************************************************************************************************************************************************
# أُثْنَاءِ الفَلْوَةِ وَالخَورِ الَّتِي تُواجِم جَزَائِرِكَ اللَّوْوُونَ وَتُحْطِمُها
# ********************************************************************************************************************************************************************************************************
# مغطى
# ********************************************************************************************************************************************************************************************************
# "الشَّجِيعُ لِمَا يُرْبَى بِالحُدُودِ وَيُعَدَّ سَاعِيَةً وَيُنْفَقُّ"
#
# This translates to English as:
#
# "The noble one, for what is raised by boundaries and counted as a walker and spent."
# ********************************************************************************************************************************************************************************************************
# من غاز ثانوي أوكسيد الكربون الموجود في الهواء
# ********************************************************************************************************************************************************************************************************
# وبِما دُونَ السِّجَلِ عنها أكْمَلَ كان
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# آخر. وفي ضمّن هُؤلاء قبائل عَرَبيَّة عديده، ضاعَ
# ********************************************************************************************************************************************************************************************************
# الْفَاتِحُ الَّذِي تُؤْمِنُ وَبِسْكَانِ فِي نُجُومٍ مَرْحَةٌ
# ********************************************************************************************************************************************************************************************************
# في حفر العروق التي تكون الذهب، ومثال ذلك
# ********************************************************************************************************************************************************************************************************
# "كما تشهد على الاختلاطات الكبيرة في الاستثمار"
# ********************************************************************************************************************************************************************************************************
# يتَّضَيَّق النابِس من أثر الخُزْ فيهم، مَع إن
# ...
# ********************************************************************************************************************************************************************************************************
# "وَأُولَئِكَ هُمُ الْمُقْرِطُونَ وَأُولَئِكَ أَصْحَابُ الْجِبَالِ"
# ********************************************************************************************************************************************************************************************************
# وبِيَنْهَا يُمِيل الْبَغْضُ إِلَى عَدْم التَّفْصِيل مَا تَبِينَ
# ********************************************************************************************************************************************************************************************************
# "الحِرف أو الحشيش أو الحض نُنَدْ أَقْرِها"
# ********************************************************************************************************************************************************************************************************
# ذات قُدوة في التَّقْدِر و التَّمَيُّز تَبِينَ الصحيح
# ********************************************************************************************************************************************************************************************************
# الْيَوْمِ أَنَا مُبْتَلٌ فَأَعْطِيْتَنِي الْكِتَابَ وَالْقُرْآنَ وَالْجِهَادَ فِي الدَّارِ إِلَّا كُنتُمْ تَعْلَمُونَ
#
# This translates to English as:
#
# "Today I am tested, so You gave me the Book and the Quran and the struggle in this world, except that you know."
# ********************************************************************************************************************************************************************************************************
# "وَهَيْ عَمِّرُ الشَّلَالَةِ فِي الصَّوَائِدِ الأُخْرَى وَالثَّي جَاءَت"
# ********************************************************************************************************************************************************************************************************
# الكيفية التي تتّبَعُ بها هذه الإشْعَادَات تَعزِز الأُوساط
# ********************************************************************************************************************************************************************************************************
# "نُموذجية تُعد مُرتبة وقية وبه هي"
#
# This translates to English as:
#
# "A model that is considered ordered and sequential, with it being"
# ********************************************************************************************************************************************************************************************************
# وَأَطْرَفُ مِن ذَٰلِكَ أَقْلَ الكَتَّابَةِ عَرَبِيَّةٌ المَبْنِي، وَهِيَ
# ********************************************************************************************************************************************************************************************************
# "ساحل البحر الأحمر بالقرب من قرية توزو الجعافرة"
# ********************************************************************************************************************************************************************************************************
# وَ لِجُسُورِ اقْدَامِهِ، يُمْرُّ ماءُ العينينْ عَلَيْكَ كُلٌّ دارٍ
# ********************************************************************************************************************************************************************************************************
# وَعُنِّا نَاسًا زَعِيمًا أَمَّ عَاشُوا دَهْرًا طِويلاً قَبْلَ
# ********************************************************************************************************************************************************************************************************
# "وجهة الميل نظرة أتيد تُريد رؤية" لـ "الحلية" المتقدمة
# ********************************************************************************************************************************************************************************************************
# من المسجد في طرف الفتية لا يُنفَك من
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# بِتَقْعَشِ مُوْسِعٍ وَ سَصْرًا أَجْوَاءَ وُدَيَّةٌ حَزْرًا تَلْكَ الخُطُوطُ
# ********************************************************************************************************************************************************************************************************
# الضائع بكثير
# ********************************************************************************************************************************************************************************************************
# آخر عند وصولنا طُفنا وسعَينا مع شيخ. كان جاري في
# ********************************************************************************************************************************************************************************************************
# وَكَانَتْ تُلِيَّةُ الْمَدْرِيَةِ (صَوْرَةٌ لِلخَدْمِ) سِنَاتِ
# ********************************************************************************************************************************************************************************************************
# وَخُلَصَ وَذَكَرَ، مِمَّا أُكْسِبَ ثَقَبَ الْقِيَادِينَ، وَحُجَّتَ النَّاسُ،
# ********************************************************************************************************************************************************************************************************
# وَكُلٌّ كَفَرَ بِذَنْبِهِ الْأُظُهُرِ وَشُيُوبَ عَهْدِهِ إِنَّ اللَّهَ يَعْلَمُ الْغَيْبَ وَالْحَقَّ وَلَا تَكُونُوا مِنَ الْمُتَفِتِّينَ
# ********************************************************************************************************************************************************************************************************
# وَطَالَما تَحْصَلَتْ عَلَيْهَا السُّؤُودُ المُنخُوِّرُ طَعَامُهَا لِلْبَدْوِ
# ********************************************************************************************************************************************************************************************************
# جُسْمَ المُجْتَمَعِ مِنْ الْفَسَادِ وَالْفَرَضِ كَانَ مِنَ الْخَزَّيْنِ
# ********************************************************************************************************************************************************************************************************
# كما يُذكر عِليّة إسحَمٌ، القَوْميّيّ من العَربَة، استُخرِزَة
# ********************************************************************************************************************************************************************************************************
# خُضْ بِسَّ شَغْوْه
# ********************************************************************************************************************************************************************************************************
# بُهْرَفٍ يُشْكِكُ كمِيلٌ وَنُفُسٍ لِّهَا عَنِ الْفَضْلِ إِلَيْكَ
# ********************************************************************************************************************************************************************************************************
# "لَيصبحُ أَحدُ هُمْ رَمْزٌ لِتَسميةٍ في البلاد وَجعلهُ"
# ********************************************************************************************************************************************************************************************************
# مُفْلُومَاتٌ سَطْحِيّةٌ
# ********************************************************************************************************************************************************************************************************
# البُحْرِ فَتَدُّقُ عُيُونًا في قاعه، كالذي نُشَاهِدُه في
# ********************************************************************************************************************************************************************************************************
# لِتَبَابِ، جُدْ أَنْ مَا ذَرَّوهُ عَنْهَا وَ عَنْمَا يَجْعَلُ
# ********************************************************************************************************************************************************************************************************
# "الله أكبر، لا إله إلا الله، محمد رسول الله"
# ********************************************************************************************************************************************************************************************************
# مشمس، دراق، غيظ، ناع، بث، نسر
# ********************************************************************************************************************************************************************************************************
# "المتصور، هو وقلم وخطا، فقد سكن العزب في"
# ********************************************************************************************************************************************************************************************************
# في إنجازهم للحروقات. وقد قام الفريق الإسلامي بتركيبه
# ********************************************************************************************************************************************************************************************************
# "فَوْضِعَا تَحْتَ شَجَرَةٍ وَشَطَرَ خُضْرَةٍ وَعَلَى مَاءِ جَارٍ"
#
# This translates to English as:
#
# "Place it under a tree and a green leaf on water from a neighbor."
# ********************************************************************************************************************************************************************************************************
# قَفْمِ بِالكَيْفِ يُضْعَفُونَ الخَيْداً يُهْدُو وَيُصْوِحُنَّا بِطَىءٍ
# ********************************************************************************************************************************************************************************************************
# العِمْرُ بَل تَطْلَقُ قَيْمَاً فَاضِبَهُ ثَابِتَهُ.
# ********************************************************************************************************************************************************************************************************
# مِّنْهَا فَأَنْكَدَةٌ مِّنْهُ بِالْمَسَاسِ، وَإِذَا كَانَ أَعْظَمُ
# ********************************************************************************************************************************************************************************************************
# "ملايين، في المتوسط، المُعدّل"
# ********************************************************************************************************************************************************************************************************
# للتعرف على زهرة واحدة من الهلاميرم
# ********************************************************************************************************************************************************************************************************
# "آلاً يزيد حموضة المياه مقارنة قد يُوتر"
# ********************************************************************************************************************************************************************************************************
# "فَإِنَّ 'العيش معاً، كمبدأ أُمِيَّرٍ إِسْتَطاعَ أَن يُثْبِتَ'"
#
# This translates to English as:
#
# "Indeed, 'living together is a principle that can be established,'"
#
# This appears to be a quote or a phrase from a religious or philosophical text.
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# "الحُرُّ عَنْ أَيْدِيَاتِكُمْ، هُوَ أَشْتَرَىٰ وَأَعْطَىٰ، وَالْمَلَائِكَةُ غَيْرُ أَيْدِيَاتِكُمْ"
#
# This translates to:
#
# "The free one from your hands, He bought and gave, and the angels are not from your hands."
# ********************************************************************************************************************************************************************************************************
# Here's the Arabic text extracted from the image:
#
# صيغة "وكالمة" تزوي في الفارسية مُعَذَّر صحرائي بين "صحراء" و "صحراء"
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# من يُفَدِّدُونَ عَلَى يُوْهِمِ وَطَنَّتَ هَبَاتِ نَصْفَيْنَ صَرَاخَةً
# ********************************************************************************************************************************************************************************************************
# "تدّريس اللغة الصينية واعداد مدّرسين الصينية من المصريين"
#
# This translates to:
#
# "Teaching Chinese language and preparing two teachers from Egyptians"
# ********************************************************************************************************************************************************************************************************
# الجماعي، ويمكن لا يُمكِن زَرْعًا يُشْتَطيع في هذا
# ********************************************************************************************************************************************************************************************************
# "أخري، فَهُكذا تَأَبَّتْ عَلَّم التَّسْمِيَات."
# ********************************************************************************************************************************************************************************************************
# "وَتَشْقَقُّ هَذَا العِزَاء لَا يَشْتَعِلَ وَلَا يُسْمَعُ"
# ********************************************************************************************************************************************************************************************************
# المُخْتَلِفَة (غاز أو سائل أو صلب)
# ********************************************************************************************************************************************************************************************************
# لا يختلف حال نسخه عن معظم اخر يحيين شيا
# ********************************************************************************************************************************************************************************************************
# مَدْرِيًا وَفَرِّيًا وَتَقَبَّلًا رُكْنَهُ مَا لَاحْضَرَةٌ أَوْسَطٌ نَصْصَارَعْ
# ********************************************************************************************************************************************************************************************************
# "كَفْرُ رِجَالٍ وَلِكُمْ مَقَامٌ مَّقَالٌ. وَقُدْ أَحْيَا بِالْمَسْتَمْ"
#
# This translates to English as:
#
# "The disbelief of men and for you there is a place of blame. And establish life with the living."
# ********************************************************************************************************************************************************************************************************
# "أَيُّمَا تَعْلَمْتَ الْحَقَّ وَأَنْفَسِيكَ مِنْهُ فَإِذَا قَالَتْ لَيْسَ إِلَٰهَ إِلَٰهُ ۚ إِنَّكَ لَتَبْشَرُ بِالْجَزَاءِ"
# ********************************************************************************************************************************************************************************************************
# المسائية الكبيرة (الشمالك والأمرار رياضات) التي ظهرت معها
# ********************************************************************************************************************************************************************************************************
# "بَلْ كَانَ الدِّاخِلُ لَّا رَّبَّعَةٌ أَقْرَأَ الشَّهْوَةَ فِي"
# ********************************************************************************************************************************************************************************************************
# Here is the Arabic text extracted from the image:
#
# آخر تَتَعَدَّى الكائنات الحية الحيويَّة على النباتات وتُنشِئُّ
# ********************************************************************************************************************************************************************************************************

# %%
import re

def remove_diacritics(text):
    diacritics = [
        '\u0617', '\u0618', '\u0619', '\u061A',  # Small high signs
        '\u064B', '\u064C', '\u064D', '\u064E', '\u064F', '\u0650',  # Tanween and basic diacritics
        '\u0651', '\u0652', '\u0653', '\u0654', '\u0655', '\u0656',  # Shadda, sukun, etc.
        '\u0657', '\u0658', '\u0659', '\u065A', '\u065B', '\u065C', 
        '\u065D', '\u065E', '\u065F', '\u0670'   # Additional Arabic diacritics
    ]
    pattern = '[' + ''.join(diacritics) + ']'
    return re.sub(pattern, '', text)
def remove_english_letters(text):
    # Regex pattern to match English letters (a-z and A-Z)
    pattern = r'[a-zA-Z]'
    # Replace English letters with an empty string
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text

# %%
df = pd.DataFrame(results)
df.head()
# Out:
#                                                                                 image  \
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x114 at 0x7DB0F6777E90>
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1182x147 at 0x7DB0F6776E90>
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=994x163 at 0x7DB0F67E6650>
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1315x224 at 0x7DB0F67E6B10>
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1224x129 at 0x7DB0F67E6FD0>
#
#                                                                        ground_truth  \
# 0                           وَإِذا ما سَأَلَتْنِي عَن مَعْنَى لَفَظَهُ "عرب" عِنْدَ
# 1              أَمّا فَهُم النُصُوصِ وَاِسْتِنْباط مَعانِيها بِوَجْهٍ صَحِيحٌ دقيق،
# 2                          تُثِير فِيها الاسود، وَهُوَ ما يَتَعارَض مَعَ اِكْتِشافِ
# 3  الجماعي، وَكادَت تَصِل إِلَى المَرْحَلَةِ الاِشْتِراكِيَّة لِسَيْطَرَةِ أَكْبَرَ
# 4                    مَعَهُ مَنْدِيلا فِيهِ جردقتان وَقَطَعَ لَحْم سَكْباج مُبَرَّد
#
#                                                                      qwenv2.5_3B
# 0                         وَإِذا ما سَأَلْتَنِي عَن مَعْنَى لَفظَةٍ "عُرب" عِندَ
# 1  أَنْ تُفْهَمَ النُّصُوصِ وَإِسْتِنْبَاطُ مَعْنَاهَا يُوجَدُ صَحِيحٌ تَفَقِيقٌ
# 2                                   "تُظهر فيها الأسود، وهو ما يتغافض مع اكتشاف"
# 3                           الجماعي، وظلت تصل إلى المرحلة الاشتراكية لسيطرة أكبر
# 4             مَا هُوَ مُنْبِذٌ فِيهِ دَرَقَاتٍ وَفَطْعَ أَحْمَسْخَاجٍ مُّرْتَدٌ

# %%
df['ground_truth'] = df['ground_truth'].apply(remove_english_letters)
df['qwenv2.5_3B'] = df['qwenv2.5_3B'].apply(remove_english_letters)

# %%
df['ground_truth_t'] = df["ground_truth"].apply(remove_diacritics)
df['qwenv2.5_3B_t'] = df["qwenv2.5_3B"].apply(remove_diacritics)

# %%
df.head()
# Out:
#                                                                                 image  \
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x114 at 0x7DB0F6777E90>
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1182x147 at 0x7DB0F6776E90>
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=994x163 at 0x7DB0F67E6650>
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1315x224 at 0x7DB0F67E6B10>
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1224x129 at 0x7DB0F67E6FD0>
#
#                                                                        ground_truth  \
# 0                           وَإِذا ما سَأَلَتْنِي عَن مَعْنَى لَفَظَهُ "عرب" عِنْدَ
# 1              أَمّا فَهُم النُصُوصِ وَاِسْتِنْباط مَعانِيها بِوَجْهٍ صَحِيحٌ دقيق،
# 2                          تُثِير فِيها الاسود، وَهُوَ ما يَتَعارَض مَعَ اِكْتِشافِ
# 3  الجماعي، وَكادَت تَصِل إِلَى المَرْحَلَةِ الاِشْتِراكِيَّة لِسَيْطَرَةِ أَكْبَرَ
# 4                    مَعَهُ مَنْدِيلا فِيهِ جردقتان وَقَطَعَ لَحْم سَكْباج مُبَرَّد
#
#                                                                      qwenv2.5_3B  \
# 0                         وَإِذا ما سَأَلْتَنِي عَن مَعْنَى لَفظَةٍ "عُرب" عِندَ
# 1  أَنْ تُفْهَمَ النُّصُوصِ وَإِسْتِنْبَاطُ مَعْنَاهَا يُوجَدُ صَحِيحٌ تَفَقِيقٌ
# 2                                   "تُظهر فيها الأسود، وهو ما يتغافض مع اكتشاف"
# 3                           الجماعي، وظلت تصل إلى المرحلة الاشتراكية لسيطرة أكبر
# 4             مَا هُوَ مُنْبِذٌ فِيهِ دَرَقَاتٍ وَفَطْعَ أَحْمَسْخَاجٍ مُّرْتَدٌ
#
#                                           ground_truth_t  \
# 0                  وإذا ما سألتني عن معنى لفظه "عرب" عند
# 1        أما فهم النصوص واستنباط معانيها بوجه صحيح دقيق،
# 2              تثير فيها الاسود، وهو ما يتعارض مع اكتشاف
# 3  الجماعي، وكادت تصل إلى المرحلة الاشتراكية لسيطرة أكبر
# 4             معه منديلا فيه جردقتان وقطع لحم سكباج مبرد
#
#                                           qwenv2.5_3B_t
# 0                 وإذا ما سألتني عن معنى لفظة "عرب" عند
# 1        أن تفهم النصوص وإستنباط معناها يوجد صحيح تفقيق
# 2           "تظهر فيها الأسود، وهو ما يتغافض مع اكتشاف"
# 3  الجماعي، وظلت تصل إلى المرحلة الاشتراكية لسيطرة أكبر
# 4                ما هو منبذ فيه درقات وفطع أحمسخاج مرتد

# %%
from jiwer import wer, cer 

# for model in ["tesseract","easyocr"]:
for model in ["qwenv2.5_3B"]:
    wer_score = wer(df["ground_truth"].tolist(), df[model].tolist())
    cer_score = cer(df["ground_truth"].tolist(), df[model].tolist())
    print(f"{model} - WER: {wer_score:.2f}, CER: {cer_score:.2f}")
# Out:
# qwenv2.5_3B - WER: 1.26, CER: 0.73

# %%
from jiwer import wer, cer 

# for model in ["tesseract","easyocr"]:
for model in ["qwenv2.5_3B_t"]:
    wer_score = wer(df["ground_truth_t"].tolist(), df[model].tolist())
    cer_score = cer(df["ground_truth_t"].tolist(), df[model].tolist())
    print(f"{model} - WER: {wer_score:.2f}, CER: {cer_score:.2f}")
# Out:
# qwenv2.5_3B_t - WER: 0.97, CER: 0.65
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.to_csv("khattat_dl_synthesizear_result.csv")
